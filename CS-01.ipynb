# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import math
import pandas as pd
def showImage(data):
    if(type(data) is list):
        for i in range(len(data)):
            cv2.imshow('Gambar'+str(i+1),data[i])
    elif((type(data).__module__) == "numpy"):
        cv2.imshow('Gambar',data)
    else:
        print('File Error')
    
    cv2.waitKey(0)
    cv2.destroyAllWindows() 

def getfeature(img):
    hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
    kernel = np.ones([3,3])
    maxg = (100, 255,   255)
    ming = ( 34, 100,  10)
    mask = cv2.inRange(hsv,ming,maxg)
    
    result = cv2.bitwise_and(img, img, mask=mask)
    r,g,b = cv2.split(result)
    d_latih = np.array([[(r.mean(),g.mean(),b.mean(),r.std(),g.std(),b.std())]])
    return d_latih

# %%
path = "D:\imageproc\Level 4\lv4-6.jpg"
img = cv2.imread(path,1)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
img.shape
# Out:
# (1477, 1108, 3)

# %%
img = cv2.resize(img,None,fx=0.3,fy=0.3)
plt.imshow(img)
plt.show()
# cvimg = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
# showImage(cvimg)
cv2.imwrite( "C:/Users/Ujang Asep/Pictures/imageresize.jpg",cv2.cvtColor(img, cv2.COLOR_RGB2BGR));

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
plt.imshow(hsv)
plt.show()
cv2.imwrite( "C:/Users/Ujang Asep/Pictures/hsv.jpg",hsv);

# %%
maxg = (100, 255,   255)
ming = ( 34, 100,  10)
mask = cv2.inRange(hsv,ming,maxg)
plt.imshow(mask)
plt.show()
cv2.imwrite( "C:/Users/Ujang Asep/Pictures/mask.jpg",mask);

# %%
showImage(mask[400:405,140:145])

# %%
kernel = np.ones([3,3])
mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
plt.imshow(mask)
plt.show()
cv2.imwrite( "C:/Users/Ujang Asep/Pictures/maskclose.jpg",mask);

# %%
result = cv2.bitwise_and(img, img, mask=mask)
plt.imshow(result)
plt.show()
showImage(result)
cv2.imwrite( "C:/Users/Ujang Asep/Pictures/result.jpg",cv2.cvtColor(result, cv2.COLOR_RGB2BGR));

# %%
r,g,b = cv2.split(result)

# %%
rh = Counter(r.ravel()) 
rh = list(rh.items())
gh = Counter(g.ravel()) 
gh = list(gh.items())
bh = Counter(b.ravel()) 
bh = list(bh.items())
rh.sort()
rg.sort()
rb.sort()

# %%
r.ravel().std(0)
# Out:
# 10.230830972925446

# %%
cnt
# Out:
# [(0, 58517),
#  (3, 2),
#  (7, 7),
#  (8, 4),
#  (9, 5),
#  (10, 8),
#  (11, 22),
#  (12, 18),
#  (13, 30),
#  (14, 30),
#  (15, 28),
#  (16, 47),
#  (17, 81),
#  (18, 67),
#  (19, 91),
#  (20, 102),
#  (21, 128),
#  (22, 154),
#  (23, 191),
#  (24, 209),
#  (25, 232),
#  (26, 271),
#  (27, 260),
#  (28, 299),
#  (29, 305),
#  (30, 371),
#  (31, 374),
#  (32, 351),
#  (33, 351),
#  (34, 351),
#  (35, 317),
#  (36, 307),
#  (37, 270),
#  (38, 239),
#  (39, 235),
#  (40, 186),
#  (41, 209),
#  (42, 145),
#  (43, 141),
#  (44, 118),
#  (45, 86),
#  (46, 76),
#  (47, 57),
#  (48, 43),
#  (49, 45),
#  (50, 30),
#  (51, 16),
#  (52, 14),
#  (53, 11),
#  (54, 14),
#  (55, 1),
#  (56, 4),
#  (58, 1),
#  (59, 1),
#  (60, 4),
#  (61, 2),
#  (62, 2),
#  (66, 2),
#  (67, 1),
#  (70, 1),
#  (76, 1),
#  (77, 1),
#  (78, 1),
#  (86, 1),
#  (90, 1),
#  (106, 1)]

# %%
r.mean()
# Out:
# 3.4417851994886997

# %%
r.ravel()
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=uint8)

# %%
r.std()
# Out:
# 10.232900713069716

# %%
r.std()
# Out:
# 10.230830972925446

# %%
g.std()
# Out:
# 16.92442368220398

# %%
b.std()
# Out:
# 7.031230474070337
